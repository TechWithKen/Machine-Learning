# %%
import pandas as pd
import numpy as np
premier_league_result = pd.read_csv("results.csv")
premier_league_stat = pd.read_csv("stats.csv")

premier_league_result.sample(50)
# Out:
#                      home_team                away_team  home_goals  \
# 2248                Sunderland         Bolton Wanderers         2.0
# 2882               Southampton                  Arsenal         2.0
# 1673                   Chelsea                  Everton         1.0
# 2103                 Liverpool               Stoke City         0.0
# 4276           AFC Bournemouth                  Chelsea         0.0
# 4191           AFC Bournemouth                  Watford         0.0
# 2856                Stoke City                  Everton         1.0
# 2784           West Ham United                   Fulham         3.0
# 143          Manchester United                  Everton         3.0
# 2216                Stoke City  Wolverhampton Wanderers         2.0
# 2839           Manchester City                Liverpool         2.0
# 470                     Fulham             Derby County         0.0
# 3430               Aston Villa        Manchester United         0.0
# 1816                Sunderland                Liverpool         0.0
# 3722         Tottenham Hotspur          AFC Bournemouth         3.0
# 1555      West Bromwich Albion        Tottenham Hotspur         1.0
# 2351                 Liverpool                  Reading         1.0
# 851                     Fulham           Wigan Athletic         2.0
# 3546      West Bromwich Albion                  Arsenal         2.0
# 1132          Blackburn Rovers     West Bromwich Albion         0.0
# 2297                   Chelsea         Newcastle United         2.0
# 609                Aston Villa         Blackburn Rovers         1.0
# 647            Manchester City                  Everton         0.0
# 1831                   Chelsea           Wigan Athletic         1.0
# 2052          Newcastle United             Swansea City         0.0
# 1501                Stoke City                  Everton         0.0
# 962           Newcastle United          West Ham United         2.0
# 188             Wigan Athletic                  Chelsea         2.0
# 2972                   Arsenal          Manchester City         1.0
# 1233                 Liverpool        Manchester United         2.0
# 2289                   Everton        Manchester United         1.0
# 2217         Manchester United      Queens Park Rangers         2.0
# 3436           West Ham United           Leicester City         1.0
# 1550                   Everton        Manchester United         3.0
# 1052                Stoke City            Middlesbrough         1.0
# 1971              Norwich City             Swansea City         3.0
# 4533         Tottenham Hotspur                  Watford         2.0
# 3568          Newcastle United                Liverpool         2.0
# 762                    Everton         Blackburn Rovers         2.0
# 3091                   Chelsea              Aston Villa         3.0
# 382               Derby County               Portsmouth         2.0
# 316           Sheffield United         Newcastle United         1.0
# 3397                   Chelsea                Liverpool         1.0
# 1952                 Liverpool  Wolverhampton Wanderers         2.0
# 2234                   Arsenal           Wigan Athletic         1.0
# 4438                 Liverpool        Tottenham Hotspur         2.0
# 4310  Brighton and Hove Albion           Crystal Palace         0.0
# 106            West Ham United                  Arsenal         1.0
# 566             Wigan Athletic         Newcastle United         1.0
# 3790                   Arsenal              Aston Villa         4.0
#
#       away_goals result     season
# 2248         2.0      D  2011-2012
# 2882         2.0      D  2013-2014
# 1673         1.0      D  2010-2011
# 2103         0.0      D  2011-2012
# 4276         1.0      A  2017-2018
# 4191         2.0      A  2017-2018
# 2856         1.0      D  2013-2014
# 2784         0.0      H  2013-2014
# 143          0.0      H  2006-2007
# 2216         1.0      H  2011-2012
# 2839         1.0      H  2013-2014
# 470          0.0      D  2007-2008
# 3430         1.0      A  2015-2016
# 1816         2.0      A  2010-2011
# 3722         0.0      H  2015-2016
# 1555         1.0      D  2010-2011
# 2351         0.0      H  2012-2013
# 851          0.0      H  2008-2009
# 3546         1.0      H  2015-2016
# 1132         0.0      D  2008-2009
# 2297         0.0      H  2012-2013
# 609          1.0      D  2007-2008
# 647          2.0      A  2007-2008
# 1831         0.0      H  2010-2011
# 2052         0.0      D  2011-2012
# 1501         0.0      D  2009-2010
# 962          2.0      D  2008-2009
# 188          3.0      A  2006-2007
# 2972         1.0      D  2013-2014
# 1233         0.0      H  2009-2010
# 2289         0.0      H  2012-2013
# 2217         0.0      H  2011-2012
# 3436         2.0      A  2015-2016
# 1550         3.0      D  2010-2011
# 1052         0.0      H  2008-2009
# 1971         1.0      H  2011-2012
# 4533         0.0      H  2017-2018
# 3568         0.0      H  2015-2016
# 762          3.0      A  2008-2009
# 3091         0.0      H  2014-2015
# 382          2.0      D  2007-2008
# 316          2.0      A  2006-2007
# 3397         1.0      D  2014-2015
# 1952         1.0      H  2011-2012
# 2234         2.0      A  2011-2012
# 4438         2.0      D  2017-2018
# 4310         0.0      D  2017-2018
# 106          0.0      H  2006-2007
# 566          0.0      H  2007-2008
# 3790         0.0      H  2015-2016

# %%
premier_df = premier_league_result.loc[premier_league_result["season"].str.contains("2018")]



# premier_df.sort_values(by="away_team", ascending=True)

# %%
premier_df["winner"] = "Draw"
premier_df["loser"] = "Draw"

premier_df.loc[premier_df["home_goals"] > premier_df["away_goals"], "winner"] = premier_df["home_team"]
premier_df.loc[premier_df["home_goals"] < premier_df["away_goals"], "winner"] = premier_df["away_team"]

premier_df.loc[premier_df["home_goals"] < premier_df["away_goals"], "loser"] = premier_df["home_team"]
premier_df.loc[premier_df["home_goals"] > premier_df["away_goals"], "loser"] = premier_df["away_team"]


premier_df["winner"].count()

premier_df.tail(20)
# Out:
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_24631/4109546904.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   premier_df["winner"] = "Draw"
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_24631/4109546904.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   premier_df["loser"] = "Draw"
#               home_team                 away_team  home_goals  away_goals  \
# 4540            Everton               Southampton         1.0         1.0
# 4541    Manchester City         Huddersfield Town         0.0         0.0
# 4542            Arsenal                   Burnley         5.0         0.0
# 4543            Chelsea                 Liverpool         1.0         0.0
# 4544       Swansea City               Southampton         0.0         1.0
# 4545            Chelsea         Huddersfield Town         1.0         1.0
# 4546     Leicester City                   Arsenal         3.0         1.0
# 4547    Manchester City  Brighton and Hove Albion         3.0         1.0
# 4548  Tottenham Hotspur          Newcastle United         1.0         0.0
# 4549    West Ham United         Manchester United         0.0         0.0
# 4550            Burnley           AFC Bournemouth         1.0         2.0
# 4551     Crystal Palace      West Bromwich Albion         2.0         0.0
# 4552  Huddersfield Town                   Arsenal         0.0         1.0
# 4553          Liverpool  Brighton and Hove Albion         4.0         0.0
# 4554  Manchester United                   Watford         1.0         0.0
# 4555   Newcastle United                   Chelsea         3.0         0.0
# 4556        Southampton           Manchester City         0.0         1.0
# 4557       Swansea City                Stoke City         1.0         2.0
# 4558  Tottenham Hotspur            Leicester City         5.0         4.0
# 4559    West Ham United                   Everton         3.0         1.0
#
#      result     season             winner                     loser
# 4540      D  2017-2018               Draw                      Draw
# 4541      D  2017-2018               Draw                      Draw
# 4542      H  2017-2018            Arsenal                   Burnley
# 4543      H  2017-2018            Chelsea                 Liverpool
# 4544      A  2017-2018        Southampton              Swansea City
# 4545      D  2017-2018               Draw                      Draw
# 4546      H  2017-2018     Leicester City                   Arsenal
# 4547      H  2017-2018    Manchester City  Brighton and Hove Albion
# 4548      H  2017-2018  Tottenham Hotspur          Newcastle United
# 4549      D  2017-2018               Draw                      Draw
# 4550      A  2017-2018    AFC Bournemouth                   Burnley
# 4551      H  2017-2018     Crystal Palace      West Bromwich Albion
# 4552      A  2017-2018            Arsenal         Huddersfield Town
# 4553      H  2017-2018          Liverpool  Brighton and Hove Albion
# 4554      H  2017-2018  Manchester United                   Watford
# 4555      H  2017-2018   Newcastle United                   Chelsea
# 4556      A  2017-2018    Manchester City               Southampton
# 4557      A  2017-2018         Stoke City              Swansea City
# 4558      H  2017-2018  Tottenham Hotspur            Leicester City
# 4559      H  2017-2018    West Ham United                   Everton

# %%
premier_df
# Out:
#      home_team          away_team  home_goals  away_goals result     season  \
# 4180       NaN     Leicester City         4.0         3.0      H  2017-2018
# 4181       NaN          Liverpool         3.0         3.0      D  2017-2018
# 4182       NaN            Burnley         2.0         3.0      A  2017-2018
# 4183       NaN  Huddersfield Town         0.0         3.0      A  2017-2018
# 4184       NaN         Stoke City         1.0         0.0      H  2017-2018
# ...        ...                ...         ...         ...    ...        ...
# 4555       NaN            Chelsea         3.0         0.0      H  2017-2018
# 4556       NaN    Manchester City         0.0         1.0      A  2017-2018
# 4557       NaN         Stoke City         1.0         2.0      A  2017-2018
# 4558       NaN     Leicester City         5.0         4.0      H  2017-2018
# 4559       NaN            Everton         3.0         1.0      H  2017-2018
#
#                  winner           loser
# 4180            Arsenal  Leicester City
# 4181               Draw            Draw
# 4182            Burnley         Chelsea
# 4183  Huddersfield Town  Crystal Palace
# 4184            Everton      Stoke City
# ...                 ...             ...
# 4555   Newcastle United         Chelsea
# 4556    Manchester City     Southampton
# 4557         Stoke City    Swansea City
# 4558  Tottenham Hotspur  Leicester City
# 4559    West Ham United         Everton
#
# [380 rows x 8 columns]

# %%
equation = np.array([[2, -3], [1, 1]])
answer = np.array([[4, 12]])



equation_inverse = np.linalg.inv(equation)

equation_inverse
equation_inverse @ answer.transpose()
# Out:
# array([[8.],
#        [4.]])

# %%
import pandas as pd
import numpy as np
premier_league_result = pd.read_csv("results.csv")
premier_league_stat = pd.read_csv("stats.csv")

premier_league_result = premier_league_result.loc[premier_league_result["season"].str.contains("2018")]
premier_league_result
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4180            Arsenal     Leicester City         4.0         3.0      H
# 4181            Watford          Liverpool         3.0         3.0      D
# 4182            Chelsea            Burnley         2.0         3.0      A
# 4183     Crystal Palace  Huddersfield Town         0.0         3.0      A
# 4184            Everton         Stoke City         1.0         0.0      H
# ...                 ...                ...         ...         ...    ...
# 4555   Newcastle United            Chelsea         3.0         0.0      H
# 4556        Southampton    Manchester City         0.0         1.0      A
# 4557       Swansea City         Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur     Leicester City         5.0         4.0      H
# 4559    West Ham United            Everton         3.0         1.0      H
#
#          season
# 4180  2017-2018
# 4181  2017-2018
# 4182  2017-2018
# 4183  2017-2018
# 4184  2017-2018
# ...         ...
# 4555  2017-2018
# 4556  2017-2018
# 4557  2017-2018
# 4558  2017-2018
# 4559  2017-2018
#
# [380 rows x 6 columns]

# %%
premier_league_result = premier_league_result.loc[premier_league_result["season"].str.contains("2018")]
premier_league_result
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4180            Arsenal     Leicester City         4.0         3.0      H
# 4181            Watford          Liverpool         3.0         3.0      D
# 4182            Chelsea            Burnley         2.0         3.0      A
# 4183     Crystal Palace  Huddersfield Town         0.0         3.0      A
# 4184            Everton         Stoke City         1.0         0.0      H
# ...                 ...                ...         ...         ...    ...
# 4555   Newcastle United            Chelsea         3.0         0.0      H
# 4556        Southampton    Manchester City         0.0         1.0      A
# 4557       Swansea City         Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur     Leicester City         5.0         4.0      H
# 4559    West Ham United            Everton         3.0         1.0      H
#
#          season
# 4180  2017-2018
# 4181  2017-2018
# 4182  2017-2018
# 4183  2017-2018
# 4184  2017-2018
# ...         ...
# 4555  2017-2018
# 4556  2017-2018
# 4557  2017-2018
# 4558  2017-2018
# 4559  2017-2018
#
# [380 rows x 6 columns]

# %%
home = premier_league_result[["home_team", "result"]]
home["club"] = home["home_team"]
home["outcome"] = home["result"].map({
    "D": "Draw",
    "H": "Win",
    "A": "Loss"
})
home = home[["club", "outcome"]]


away = premier_league_result[["away_team", "result"]]
away["club"] = away["away_team"]
away["outcome"] = away["result"].map({
    "D": "Draw",
    "H": "Loss",
    "A": "Win"
})

away = away[["club", "outcome"]]

all_results = pd.concat([home, away], ignore_index=True)
all_results

final_premier_league = all_results.pivot_table(columns="outcome", index="club", aggfunc="size")
final_premier_league
# Out:
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/2832456971.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home["club"] = home["home_team"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/2832456971.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home["outcome"] = home["result"].map({
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/2832456971.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away["club"] = away["away_team"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/2832456971.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away["outcome"] = away["result"].map({
# outcome                   Draw  Loss  Win
# club
# AFC Bournemouth             11    16   11
# Arsenal                      6    13   19
# Brighton and Hove Albion    13    16    9
# Burnley                     12    12   14
# Chelsea                      7    10   21
# Crystal Palace              11    16   11
# Everton                     10    15   13
# Huddersfield Town           10    19    9
# Leicester City              11    15   12
# Liverpool                   12     5   21
# Manchester City              4     2   32
# Manchester United            6     7   25
# Newcastle United             8    18   12
# Southampton                 15    16    7
# Stoke City                  12    19    7
# Swansea City                 9    21    8
# Tottenham Hotspur            8     7   23
# Watford                      8    19   11
# West Bromwich Albion        13    19    6
# West Ham United             12    16   10

# %%
#final_premier_league["points"] = (final_premier_league["Draw"]*1) + (final_premier_league["Win"]*3)
final_premier_league.sum(axis=1)
# Out:
# club
# AFC Bournemouth             38
# Arsenal                     38
# Brighton and Hove Albion    38
# Burnley                     38
# Chelsea                     38
# Crystal Palace              38
# Everton                     38
# Huddersfield Town           38
# Leicester City              38
# Liverpool                   38
# Manchester City             38
# Manchester United           38
# Newcastle United            38
# Southampton                 38
# Stoke City                  38
# Swansea City                38
# Tottenham Hotspur           38
# Watford                     38
# West Bromwich Albion        38
# West Ham United             38
# dtype: int64

# %%
home = premier_league_result[["home_team", "home_goals"]]
home['club'] = home["home_team"]
home["goals"] = home["home_goals"]
home = home[["club", "goals"]]

away = premier_league_result[["away_team", "away_goals"]]
away["club"] = away["away_team"]
away["goals"] = away["away_goals"]

away = away[["club", "goals"]]

all_goals = pd.concat([home, away],ignore_index=True)
total_goals = all_goals.pivot_table(index="club", values="goals", aggfunc="sum")

league_table = final_premier_league.merge(total_goals, on="club", how="inner")
league_table.rename(columns={"goals": "GF", "Played": "P", "Draw": "D", "Loss": "L", "Win": "W", "points": "PTS"}, inplace=True)
# Out:
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/1781757404.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home['club'] = home["home_team"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/1781757404.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home["goals"] = home["home_goals"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/1781757404.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away["club"] = away["away_team"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/1781757404.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away["goals"] = away["away_goals"]

# %%
premier_league_result
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4180            Arsenal     Leicester City         4.0         3.0      H
# 4181            Watford          Liverpool         3.0         3.0      D
# 4182            Chelsea            Burnley         2.0         3.0      A
# 4183     Crystal Palace  Huddersfield Town         0.0         3.0      A
# 4184            Everton         Stoke City         1.0         0.0      H
# ...                 ...                ...         ...         ...    ...
# 4555   Newcastle United            Chelsea         3.0         0.0      H
# 4556        Southampton    Manchester City         0.0         1.0      A
# 4557       Swansea City         Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur     Leicester City         5.0         4.0      H
# 4559    West Ham United            Everton         3.0         1.0      H
#
#          season
# 4180  2017-2018
# 4181  2017-2018
# 4182  2017-2018
# 4183  2017-2018
# 4184  2017-2018
# ...         ...
# 4555  2017-2018
# 4556  2017-2018
# 4557  2017-2018
# 4558  2017-2018
# 4559  2017-2018
#
# [380 rows x 6 columns]

# %%
home = premier_league_result[["home_team", "away_goals"]]
home['club'] = home["home_team"]
home["goals"] = home["away_goals"]

home = home[["club", "goals"]]

away = premier_league_result[["away_team", "home_goals"]]
away["club"] = away["away_team"]
away["goals"] = away["home_goals"]

away = away[["club", "goals"]]
away

all_goals = pd.concat([home, away],ignore_index=True)
against_goals = all_goals.pivot_table(index="club", values="goals", aggfunc="sum")
against_goals
# Out:
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/3475939722.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home['club'] = home["home_team"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/3475939722.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home["goals"] = home["away_goals"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/3475939722.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away["club"] = away["away_team"]
# /var/folders/kz/wkqtl4j969d5fgytvys6k_jw0000gn/T/ipykernel_33123/3475939722.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   away["goals"] = away["home_goals"]
#                           goals
# club
# AFC Bournemouth            61.0
# Arsenal                    51.0
# Brighton and Hove Albion   54.0
# Burnley                    39.0
# Chelsea                    38.0
# Crystal Palace             55.0
# Everton                    58.0
# Huddersfield Town          58.0
# Leicester City             60.0
# Liverpool                  38.0
# Manchester City            27.0
# Manchester United          28.0
# Newcastle United           47.0
# Southampton                56.0
# Stoke City                 68.0
# Swansea City               56.0
# Tottenham Hotspur          36.0
# Watford                    64.0
# West Bromwich Albion       56.0
# West Ham United            68.0

# %%
league_table = league_table.merge(against_goals, on="club", how="inner")

# %%
league_table.rename(columns={"goals":"GA"}, inplace=True)
league_table = league_table.sort_values(by="PTS", ascending=False)

league_table["GD"] = league_table["GF"] - league_table["GA"]
remove_col = league_table.columns.tolist()

remove_col.remove("PTS")
remove_col.append("PTS")

league_table = league_table[remove_col]

league_table
# Out:
#                            P   D   L   W     GF    GA    GD  PTS
# club
# Manchester City           38   4   2  32  106.0  27.0  79.0  100
# Manchester United         38   6   7  25   68.0  28.0  40.0   81
# Tottenham Hotspur         38   8   7  23   74.0  36.0  38.0   77
# Liverpool                 38  12   5  21   84.0  38.0  46.0   75
# Chelsea                   38   7  10  21   62.0  38.0  24.0   70
# Arsenal                   38   6  13  19   74.0  51.0  23.0   63
# Burnley                   38  12  12  14   36.0  39.0  -3.0   54
# Everton                   38  10  15  13   44.0  58.0 -14.0   49
# Leicester City            38  11  15  12   56.0  60.0  -4.0   47
# Crystal Palace            38  11  16  11   45.0  55.0 -10.0   44
# AFC Bournemouth           38  11  16  11   45.0  61.0 -16.0   44
# Newcastle United          38   8  18  12   39.0  47.0  -8.0   44
# West Ham United           38  12  16  10   48.0  68.0 -20.0   42
# Watford                   38   8  19  11   44.0  64.0 -20.0   41
# Brighton and Hove Albion  38  13  16   9   34.0  54.0 -20.0   40
# Huddersfield Town         38  10  19   9   28.0  58.0 -30.0   37
# Southampton               38  15  16   7   37.0  56.0 -19.0   36
# Stoke City                38  12  19   7   35.0  68.0 -33.0   33
# Swansea City              38   9  21   8   28.0  56.0 -28.0   33
# West Bromwich Albion      38  13  19   6   31.0  56.0 -25.0   31

# %%
premier_league_result["season"]
# Out:
# 4180    2017-2018
# 4181    2017-2018
# 4182    2017-2018
# 4183    2017-2018
# 4184    2017-2018
#           ...
# 4555    2017-2018
# 4556    2017-2018
# 4557    2017-2018
# 4558    2017-2018
# 4559    2017-2018
# Name: season, Length: 380, dtype: object

# %%
premier_league_result
# Out:
#               home_team          away_team  home_goals  away_goals result  \
# 4180            Arsenal     Leicester City         4.0         3.0      H
# 4181            Watford          Liverpool         3.0         3.0      D
# 4182            Chelsea            Burnley         2.0         3.0      A
# 4183     Crystal Palace  Huddersfield Town         0.0         3.0      A
# 4184            Everton         Stoke City         1.0         0.0      H
# ...                 ...                ...         ...         ...    ...
# 4555   Newcastle United            Chelsea         3.0         0.0      H
# 4556        Southampton    Manchester City         0.0         1.0      A
# 4557       Swansea City         Stoke City         1.0         2.0      A
# 4558  Tottenham Hotspur     Leicester City         5.0         4.0      H
# 4559    West Ham United            Everton         3.0         1.0      H
#
#          season
# 4180  2017-2018
# 4181  2017-2018
# 4182  2017-2018
# 4183  2017-2018
# 4184  2017-2018
# ...         ...
# 4555  2017-2018
# 4556  2017-2018
# 4557  2017-2018
# 4558  2017-2018
# 4559  2017-2018
#
# [380 rows x 6 columns]

# %%
premier_league_stat.head(40)
# Out:
#                  team  wins  losses  goals  total_yel_card  total_red_card  \
# 0   Manchester United  28.0     5.0   83.0            60.0             1.0
# 1             Chelsea  24.0     3.0   64.0            62.0             4.0
# 2           Liverpool  20.0    10.0   57.0            44.0             0.0
# 3             Arsenal  19.0     8.0   63.0            59.0             3.0
# 4   Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
# 5    Bolton Wanderers  16.0    14.0   47.0            84.0             4.0
# 6             Reading  16.0    15.0   52.0            38.0             3.0
# 7    Blackburn Rovers  15.0    16.0   52.0            77.0             6.0
# 8             Everton  15.0    10.0   52.0            65.0             2.0
# 9          Portsmouth  14.0    12.0   45.0            48.0             1.0
# 10      Middlesbrough  12.0    16.0   44.0            64.0             2.0
# 11    West Ham United  12.0    21.0   35.0            85.0             2.0
# 12        Aston Villa  11.0    10.0   43.0            48.0             1.0
# 13    Manchester City  11.0    18.0   29.0            59.0             4.0
# 14   Newcastle United  11.0    17.0   38.0            65.0             1.0
# 15   Sheffield United  10.0    20.0   32.0            68.0             2.0
# 16     Wigan Athletic  10.0    20.0   37.0            73.0             3.0
# 17  Charlton Athletic   8.0    20.0   34.0            56.0             4.0
# 18             Fulham   8.0    15.0   38.0            56.0             3.0
# 19            Watford   5.0    20.0   29.0            45.0             2.0
# 20  Manchester United  27.0     5.0   80.0            51.0             2.0
# 21            Chelsea  25.0     3.0   65.0            63.0             5.0
# 22            Arsenal  24.0     3.0   74.0            55.0             3.0
# 23          Liverpool  21.0     4.0   67.0            45.0             1.0
# 24            Everton  19.0    11.0   55.0            40.0             3.0
# 25        Aston Villa  16.0    10.0   71.0            54.0             4.0
# 26         Portsmouth  16.0    13.0   48.0            55.0             3.0
# 27   Blackburn Rovers  15.0    10.0   50.0            72.0             6.0
# 28    Manchester City  15.0    13.0   45.0            50.0             4.0
# 29    West Ham United  13.0    15.0   42.0            63.0             1.0
# 30   Newcastle United  11.0    17.0   45.0            63.0             1.0
# 31         Sunderland  11.0    21.0   36.0            65.0             4.0
# 32  Tottenham Hotspur  11.0    14.0   66.0            51.0             1.0
# 33      Middlesbrough  10.0    16.0   43.0            86.0             2.0
# 34            Reading  10.0    22.0   41.0            59.0             5.0
# 35     Wigan Athletic  10.0    18.0   34.0            59.0             4.0
# 36   Bolton Wanderers   9.0    19.0   36.0            76.0             0.0
# 37    Birmingham City   8.0    19.0   46.0            70.0             3.0
# 38             Fulham   8.0    18.0   38.0            55.0             6.0
# 39       Derby County   1.0    29.0   20.0            63.0             1.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0               698.0                 256.0          21.0         12.0  ...
# 1               636.0                 216.0          14.0         16.0  ...
# 2               668.0                 214.0          15.0          8.0  ...
# 3               638.0                 226.0          19.0         10.0  ...
